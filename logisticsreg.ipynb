# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv("/content/student_performance_dataset.csv")

# %%
print(df.head())
# Out:
#    High school GPA  Number of extracurricular activities  Parental income  \
# 0             3.76                                     7         55116.34
# 1             2.48                                     2         52752.89
# 2             3.58                                     9         62770.22
# 3             3.03                                     6         63357.91
# 4             2.03                                     2         69457.67
#
#    Number of hours studied per week  Performance in an entrance test  \
# 0                                23                            56.93
# 1                                19                            24.77
# 2                                30                            87.37
# 3                                 0                            99.25
# 4                                16                            60.10
#
#    Distance from college (km) Internet availability at home Final year result
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   High school GPA                       100 non-null    float64
#  1   Number of extracurricular activities  100 non-null    int64
#  2   Parental income                       100 non-null    float64
#  3   Number of hours studied per week      100 non-null    int64
#  4   Performance in an entrance test       100 non-null    float64
#  5   Distance from college (km)            100 non-null    float64
#  6   Internet availability at home         100 non-null    object
#  7   Final year result                     100 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 6.4+ KB
# None

# %%
label_encoder = LabelEncoder()
df["Internet availability at home"] = label_encoder.fit_transform(df["Internet availability at home"])
df["Final year result"] = label_encoder.fit_transform(df["Final year result"])

# %%
X = df.drop("Final year result", axis=1)
y = df["Final year result"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_prob_df = pd.DataFrame(y_prob, columns=["Probability_Fail", "Probability_Pass"])
y_prob_df["Predicted_Label"] = y_pred
y_prob_df["Actual_Label"] = y_test.values

# %%
print("Accuracy:", accuracy)
print("\nClassification Report:\n", report)
print("\nPredicted Probabilities with Labels:\n")
print(y_prob_df.head(10))
# Out:
# Accuracy: 0.7
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         Fail       0.33      0.50      0.40         4
#         Pass       0.86      0.75      0.80        16
#
#     accuracy                           0.70        20
#    macro avg       0.60      0.62      0.60        20
# weighted avg       0.75      0.70      0.72        20
#
#
# Predicted Probabilities with Labels:
#
#    Probability_Fail  Probability_Pass  Predicted_Label  Actual_Label
# 0          0.464885          0.535115                1             0
# 1          0.736525          0.263475                0             1
# 2          0.135056          0.864944                1             1
# 3          0.343493          0.656507                1             1
# 4          0.410629          0.589371                1             1
# 5          0.274861          0.725139                1             1
# 6          0.641622          0.358378                0             1
# ...
