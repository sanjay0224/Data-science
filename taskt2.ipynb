# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %% [markdown]
# loading dataset

# %%
df=pd.read_csv('/content/Ice Cream.csv')

# %% [markdown]
# Data exploration

# %%
print(df.head())
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB
# None

# %%
print(df.describe())
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %% [markdown]
# Preprocessing

# %%
df.dropna(inplace=True)

# %% [markdown]
# feature selection

# %%
x=df[['Temperature']] #twodimensional
y=df[['Revenue']]

# %% [markdown]
# visualize

# %%
plt.scatter(x,y)
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.title('Temperature vs Revenue')
plt.grid(True)
plt.show()

# %% [markdown]
# train test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# model implementation

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# prediction variable

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# evaluation metrics

# %%
print("msr:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# msr: 25.543958747446354

# %%
print("mae:",mean_absolute_error(y_test,y_pred))
# Out:
# 19.195652579103704

# %%
print("R2_Score:",r2_score(y_test,y_pred))
# Out:
# R2_Score: 0.9771509516333023

# %% [markdown]
# result plot visualization

# %%
plt.scatter(x_test,y_test,color='blue',label='Actual')
plt.plot(x_test,y_pred,color='red',label='Predicted')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.title('Temperature,Revenue vs Actual predictions')
plt.legend()
plt.grid(True)
plt.show()
